# %% [markdown]
# # MILD One-Click Colab
#
# Installs dependencies, downloads weights, updates configs, runs a 1-epoch smoke test.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python -m pip install -r requirements.txt

# %%
# Optional: pin a CUDA build if you hit torch/CUDA mismatch errors
# !python -m pip install --upgrade --index-url https://download.pytorch.org/whl/cu121 torch torchvision

# %%
# Prefetch weights to avoid first-epoch stalls
import timm
from transformers import AutoModel, AutoTokenizer
_ = timm.create_model('convnext_tiny', pretrained=True)
_ = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
_ = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
print('Weights downloaded')

# %%
# Update these paths for your dataset
DATASET_ROOT = '/content/drive/MyDrive/your_dataset_root'
DATASET_URL = ''  # Optional: direct URL to a zip
if DATASET_URL:
    # !python tools/colab_setup.py --dataset-root "{DATASET_ROOT}" --dataset-url "{DATASET_URL}" --safe --epochs 1 --print
else:
    # !python tools/colab_setup.py --dataset-root "{DATASET_ROOT}" --safe --epochs 1 --print

# %%
# !nvidia-smi

# %%
# !python tools/train.py --config configs/train.yaml --device auto
